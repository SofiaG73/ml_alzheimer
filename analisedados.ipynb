# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("dataset_CB23.csv")

# %%
df
# Out:
#       patient_id sex  age_years  years_education visit  APOE4 apoe_result  \
# 0              1   f         51               11    V1    0.0       e3/e3
# 1              2   m         76               10    V1    2.0       e4/e4
# 2              3   f         61               14    V1    0.0       e3/e3
# 3              4   f         53               10    V1    1.0       e2/e4
# 4              5   f         77               20    V1    1.0       e3/e4
# ...          ...  ..        ...              ...   ...    ...         ...
# 2995         996   m         93               12    V3    NaN         NaN
# 2996         997   m         86               13    V3    1.0       e3/e4
# 2997         998   m         66               20    V3    1.0       e3/e4
# 2998         999   m         76               16    V3    1.0       e3/e4
# 2999        1000  un         63               14    V3    2.0       e4/e4
#
#      family_dementia_history  ptau_result  ttau_result  ...  Depression  \
# ...

# %%
# df.set_index('patient_id', inplace=True)

# %%
df
# Out:
#            sex  age_years  years_education visit  APOE4 apoe_result  \
# patient_id
# 1            f         51               11    V1    0.0       e3/e3
# 2            m         76               10    V1    2.0       e4/e4
# 3            f         61               14    V1    0.0       e3/e3
# 4            f         53               10    V1    1.0       e2/e4
# 5            f         77               20    V1    1.0       e3/e4
# ...         ..        ...              ...   ...    ...         ...
# 996          m         93               12    V3    NaN         NaN
# 997          m         86               13    V3    1.0       e3/e4
# 998          m         66               20    V3    1.0       e3/e4
# 999          m         76               16    V3    1.0       e3/e4
# 1000        un         63               14    V3    2.0       e4/e4
#
#            family_dementia_history  ptau_result  ttau_result  abeta42_result  \
# patient_id
# ...

# %%
df.shape
# Out:
# (3000, 29)

# %%
df.columns
# Out:
# Index(['patient_id', 'sex', 'age_years', 'years_education', 'visit', 'APOE4',
#        'apoe_result', 'family_dementia_history', 'ptau_result', 'ttau_result',
#        'abeta42_result', 'AMYL', 'TAUO', 'NEUROD', 'ATN', 'MONTHS',
#        'mmse_total', 'np_date', 'gds_total', 'Depression', 'cdr_global', 'DX',
#        'cdr_sob', 'LHVL', 'LHVR', 'LHV', 'LWMV', 'VASCULAR', 'DXCHANGE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# patient_id                   int64
# sex                         object
# age_years                    int64
# years_education              int64
# visit                       object
# APOE4                      float64
# apoe_result                 object
# family_dementia_history     object
# ptau_result                float64
# ttau_result                float64
# abeta42_result             float64
# AMYL                       float64
# TAUO                       float64
# NEUROD                     float64
# ATN                         object
# MONTHS                     float64
# mmse_total                 float64
# np_date                     object
# gds_total                  float64
# Depression                 float64
# cdr_global                 float64
# DX                          object
# cdr_sob                    float64
# LHVL                       float64
# LHVR                       float64
# LHV                        float64
# LWMV                       float64
# ...

# %%
# per column missing values
df.isnull().sum()
# Out:
# patient_id                    0
# sex                           0
# age_years                     0
# years_education               0
# visit                         0
# APOE4                       309
# apoe_result                 309
# family_dementia_history       0
# ptau_result                2100
# ttau_result                2100
# abeta42_result             2100
# AMYL                       2100
# TAUO                       2100
# NEUROD                     2100
# ATN                        2100
# MONTHS                      461
# mmse_total                  287
# np_date                     287
# gds_total                   268
# Depression                  268
# cdr_global                  289
# DX                          289
# cdr_sob                     289
# LHVL                       2000
# LHVR                       2000
# LHV                        2000
# LWMV                       2000
# VASCULAR                   2000
# DXCHANGE                   2190
# ...

# %%
df["ttau_result"]
# Out:
# 0       331.0
# 1       223.0
# 2       202.0
# 3        80.0
# 4         NaN
#         ...
# 2995      NaN
# 2996      NaN
# 2997      NaN
# 2998      NaN
# 2999      NaN
# Name: ttau_result, Length: 3000, dtype: float64
